# %%
# %matplotlib inline

import pandas as pd, numpy as np, seaborn as sns
import matplotlib.pyplot as plt

from qiime.parse import parse_mapping_file
from qiime.format import format_mapping_file
from skbio.io.util import open_file
from scipy.stats import pearsonr, spearmanr
from biom import load_table

from IPython.display import Image

def load_mf(fn):
    with open_file(fn, 'U') as f:
        mapping_data, header, _ = parse_mapping_file(f)
        _mapping_file = pd.DataFrame(mapping_data, columns=header)
        _mapping_file.set_index('SampleID', inplace=True)
    return _mapping_file

def write_mf(f, _df):
    with open_file(f, 'w') as fp:
        lines = format_mapping_file(['SampleID'] + _df.columns.tolist(),
                                    list(_df.itertuples()))
        fp.write(lines+'\n')

# %%
def exploding_panda(_bt):
    """BIOM->Pandas dataframe converter

    Parameters
    ----------
    _bt : biom.Table
        BIOM table

    Returns
    -------
    pandas.DataFrame
        The BIOM table converted into a DataFrame
        object.
        
    References
    ----------
    Based on this answer on SO:
    http://stackoverflow.com/a/17819427/379593
    """
    m = _bt.matrix_data
    data = [pd.SparseSeries(m[i].toarray().ravel()) for i in np.arange(m.shape[0])]
    out = pd.SparseDataFrame(data, index=_bt.ids('observation'),
                             columns=_bt.ids('sample'))
    
    return out.to_dense()

# %% [markdown]
# We filter out OTUs that are not present in at least 10 percent of the samples and in at least 20 percent of the sample. This helps us reduce the penalization that we get from doing multiple comparisons and to only assess the statistical significance of microbes that are well represented by the samples (HT to Kyle Bittinger, as I discussed a lot about this with him at the Quebec QIIME workshop).

# %%
# %%bash
#
# mkdir -p stats/group-significance/no-diarrhea/
#
# # 5 percent
# filter_otus_from_otu_table.py -s 8 \
# -i otu_table.15000.no-diarrhea.biom \
# -o stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.5pct.biom
#
# # 10 percent
# filter_otus_from_otu_table.py -s 16 \
# -i otu_table.15000.no-diarrhea.biom \
# -o stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.10pct.biom
#
# # 20 percent
# filter_otus_from_otu_table.py -s 32 \
# -i otu_table.15000.no-diarrhea.biom \
# -o stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.20pct.biom
#
# # 40 percent
# filter_otus_from_otu_table.py -s 64 \
# -i otu_table.15000.no-diarrhea.biom \
# -o stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.40pct.biom

# %%
# %%bash -e
#
# # 5 percent
# summarize_taxa.py \
# -i stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.5pct.biom \
# -o stats/group-significance/no-diarrhea/taxa-summaries-5pct/
#
# # genus
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-5pct/otu_table.15000.no-diarrhea.5pct_L6.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-5pct-L6.tsv \
# -s kruskal_wallis
#
# # family
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-5pct/otu_table.15000.no-diarrhea.5pct_L5.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-5pct-L5.tsv \
# -s kruskal_wallis
#
# # order
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-5pct/otu_table.15000.no-diarrhea.5pct_L4.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-5pct-L4.tsv \
# -s kruskal_wallis
#
# # class
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-5pct/otu_table.15000.no-diarrhea.5pct_L3.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-5pct-L3.tsv \
# -s kruskal_wallis
#
# # 10 percent
# summarize_taxa.py \
# -i stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.10pct.biom \
# -o stats/group-significance/no-diarrhea/taxa-summaries-10pct/
#
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-10pct/otu_table.15000.no-diarrhea.10pct_L6.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-10pct-L6.tsv \
# -s kruskal_wallis
#
# # 40 percent
# summarize_taxa.py \
# -i stats/group-significance/no-diarrhea/otu_table.15000.no-diarrhea.40pct.biom \
# -o stats/group-significance/no-diarrhea/taxa-summaries-40pct/
#
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-40pct/otu_table.15000.no-diarrhea.40pct_L6.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-40pct-L6.tsv \
# -s kruskal_wallis
#
# group_significance.py \
# -i stats/group-significance/no-diarrhea/taxa-summaries-40pct/otu_table.15000.no-diarrhea.40pct_L4.biom \
# -m mapping-file-full.alpha.L6index.txt \
# -c disease_stat \
# -o stats/group-significance/no-diarrhea/kruskall-wallis-40pct-L4.tsv \
# -s kruskal_wallis
# Out:
# Warning: No metadata in biom table. Won't alter calculations.
# Warning: No metadata in biom table. Won't alter calculations.
# Warning: No metadata in biom table. Won't alter calculations.
# Warning: No metadata in biom table. Won't alter calculations.

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

sns.set(font="monospace")
sns.set_context("talk")

bt = load_table('stats/group-significance/no-diarrhea/taxa-summaries-40pct/otu_table.15000.no-diarrhea.40pct_L6.biom')
mf = load_mf('mapping-file-full.alpha.L6index.txt')
mf = mf.loc[bt.ids('sample')]

# dataframe from the group significance table
gsdf = pd.read_csv('stats/group-significance/no-diarrhea/kruskall-wallis-40pct-L6.tsv',
                   sep='\t')
gsdf = gsdf[gsdf['Bonferroni_P'] < 0.05]

current_palette = sns.color_palette()
cat_colors = dict(zip(mf.disease_stat.unique(),
                      current_palette[:3]))

# keep only the significant OTUs
bt.filter(gsdf.OTU.astype(str), axis='observation', inplace=True)
bt.norm()

df = exploding_panda(bt)

colors = []
for sid in bt.ids('sample'):
    colors.append(cat_colors[mf.loc[sid].disease_stat])

x = sns.clustermap(df, method="average",
                   figsize=(20, 20), col_colors=colors,
                   cmap=plt.get_cmap("Oranges"))

handles = []
for key, value in cat_colors.iteritems():
    handles.append(mpatches.Patch(color=value, label=key))

plt.legend(handles=handles)
# x.savefig('clustermap-L6.pdf')

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

sns.set(font="monospace")
sns.set_context("talk")

bt = load_table('stats/group-significance/no-diarrhea/taxa-summaries-10pct/otu_table.15000.no-diarrhea.10pct_L6.biom')

mf = load_mf('mapping-file-full.alpha.L6index.txt')
mf = mf.loc[bt.ids('sample')]

# dataframe from the group significance table
gsdf = pd.read_csv('stats/group-significance/no-diarrhea/kruskall-wallis-10pct-L6.tsv',
                   sep='\t')
gsdf = gsdf[gsdf['Bonferroni_P'] < 0.05]

current_palette = sns.color_palette()
cat_colors = dict(zip(mf.disease_stat.unique(),
                      current_palette[:3]))

# keep only the significant OTUs
bt.filter(gsdf.OTU.astype(str), axis='observation', inplace=True)
bt.norm()

df = exploding_panda(bt)

sample_order = mf[mf.disease_stat == 'healthy'].index.tolist() + mf[mf.disease_stat != 'healthy'].index.tolist()
df = df[sample_order]

colors = []
for sid in df.columns:
    colors.append(cat_colors[mf.loc[sid].disease_stat])

x = sns.clustermap(df, method="average",
                   row_cluster=True, col_cluster=False,
                   figsize=(20, 20), col_colors=colors,
                   cmap=plt.get_cmap("Oranges"))

handles = []
for key, value in cat_colors.iteritems():
    handles.append(mpatches.Patch(color=value, label=key))

plt.legend(handles=handles)
# x.savefig('clustermap-L6.pdf')

# %%
df = exploding_panda(bt)

# sample_order = (mf.disease_stat == 'healthy').index.tolist() + (mf.disease_stat != 'healthy').index.tolist()
# df = df[sample_order]

# %%
h = exploding_panda(bt)

# %%
h
# Out:
#                                                       AHD.31    AHD.35  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000717  0.004583
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000215  0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.004662  0.000141
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.015206  0.000071
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.701980  0.769442
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.276287  0.212014
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.000143  0.013537
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000000  0.000071
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.000789  0.000141
#
#                                                       AHD.37    AHD.43  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.002648  0.004819
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000209  0.000163
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.000976  0.000163
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.023207  0.000408
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.679350  0.937924
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.291728  0.049253
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.000279  0.003839
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000000  0.000327
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.001603  0.003104
#
#                                                       AHD.51    AHD.61  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.001168  0.079972
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000000  0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.000311  0.000315
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.017515  0.002049
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.769656  0.586905
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.207380  0.219666
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.003737  0.103924
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000078  0.007091
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.000156  0.000079
#
#                                                       AHD.71    AHD.73  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.059526  0.003881
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000000  0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.000779  0.000139
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.000000  0.000970
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.779028  0.940679
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.043606  0.043867
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.107285  0.000970
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.009604  0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.000173  0.009494
#
#                                                       AHD.74    AHD.82  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.007092  0.050780
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000076  0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.018226  0.000075
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.005262  0.000225
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.762068  0.709271
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.200869  0.172667
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.005109  0.064581
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000381  0.002100
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.000915  0.000300
#
#                                                          ...         \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales       ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...       ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...       ...
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       ...
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...       ...
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...       ...
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...       ...
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...       ...
#
#                                                     Sweden.IBD.062A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.000153
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.000000
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.971019
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.028600
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000000
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000229
#
#                                                     Sweden.IBD.064A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.001946
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.000156
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.000078
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.042510
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.953597
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000623
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.001090
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000
#
#                                                     Sweden.IBD.065A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.023728
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.002447
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.149926
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.650351
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.071079
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.028623
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000213
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.073633
#
#                                                     Sweden.IBD.066A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.028820
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.029995
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.342000
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.578667
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.007831
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.006265
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.002036
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.004386
#
#                                                     Sweden.IBD.067A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.464945
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.005698
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.498846
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.030294
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000216
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000
#
#                                                     Sweden.IBD.098A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000100
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.027284
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.401059
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.015391
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.459025
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.096642
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000100
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000400
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000
#
#                                                     Sweden.IBD.099A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.021508
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.671106
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.069728
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.234367
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.003062
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000077
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000153
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000
#
#                                                     Sweden.IBD.100A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000581
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.008612
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.180472
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.004742
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.538030
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.266789
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000774
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000
#
#                                                     Sweden.IBD.101A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.028760
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.508667
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.001788
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.381112
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.079363
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000155
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000155
#
#                                                     Sweden.IBD.102A
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.004677
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000557
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.029733
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.070490
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.879844
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.010134
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000780
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000780
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.003007
#
# [9 rows x 149 columns]

# %%
len(sample_order)
# Out:
# 298

# %%
h.reindex(columns=sample_order)
# Out:
#                                                     California.HC21  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.001342
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.001174
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.021136
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.754173
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.024155
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000000
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.198021
#
#                                                     Sweden.IBD.060A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000165
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000576
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.391913
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.001153
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.509676
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.072964
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000000
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.023553
#
#                                                     Sweden.HC.7    AHD.89  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     0.039750  0.018896
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales     0.000070  0.002013
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     0.000140  0.028576
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...     0.000070  0.055758
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     0.627524  0.648029
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...     0.290662  0.030512
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...     0.041012  0.209479
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...     0.000631  0.004104
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...     0.000140  0.002633
#
#                                                       Nor.C2   Nor.C10  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.000161  0.000077
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.002010  0.028256
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.460437  0.491631
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.000000  0.000000
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.481264  0.151413
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.024767  0.000077
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.000000  0.000384
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000000  0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.031361  0.328163
#
#                                                     Finland.HC.13  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0.023960
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales       0.000293
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...       0.000366
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...       0.003444
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0.825689
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...       0.063086
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...       0.081331
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...       0.001612
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0.000220
#
#                                                     Sweden.IBD.098A  Leda.A61  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000100  0.055417
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.027284  0.000151
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.401059  0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.015391  0.000529
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.459025  0.552812
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.096642  0.079049
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000100  0.122763
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000400  0.006116
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000000  0.183163
#
#                                                     France.DC10     ...      \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...     0.000165     ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales     0.000989     ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...     0.002471     ...
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...     0.000000     ...
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...     0.929813     ...
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...     0.006261     ...
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...     0.060219     ...
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...     0.000000     ...
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...     0.000082     ...
#
#                                                     Finland.HC.12  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0.069551
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales       0.000080
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...       0.001045
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...       0.005628
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0.789177
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...       0.074214
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...       0.054354
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...       0.003457
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0.002493
#
#                                                     California.HC25  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...         0.000638
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales         0.000080
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...         0.000319
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...         0.036762
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...         0.870255
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...         0.091308
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...         0.000080
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...         0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...         0.000558
#
#                                                     Finland.HC.19  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0.081647
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales       0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...       0.000161
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...       0.001124
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0.746949
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...       0.064868
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...       0.100594
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...       0.004576
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0.000080
#
#                                                     California.HC1  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...        0.001009
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales        0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...        0.000155
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...        0.145329
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...        0.801598
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...        0.051676
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...        0.000155
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...        0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...        0.000078
#
#                                                     Finland.HC.21  Leda.A13  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...       0.008234  0.001029
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales       0.000000  0.000158
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...       0.000000  0.355571
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...       0.001047  0.000158
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...       0.600419  0.510684
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...       0.046057  0.132241
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...       0.344103  0.000079
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...       0.000140  0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...       0.000000  0.000079
#
#                                                     Leda.C53  Sweden.IBD.064A  \
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.290344         0.001946
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000000         0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.000000         0.000156
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.002241         0.000078
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.584329         0.042510
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.071442         0.953597
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.051550         0.000623
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000000         0.001090
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.000093         0.000000
#
#                                                       AHD.37  Mel.TX.HC4
# k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__...  0.002648    0.001500
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales  0.000209    0.000000
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...  0.000976    0.000068
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Turicib...  0.023207    0.000000
# k__Bacteria;p__Firmicutes;c__Clostridia;o__Clos...  0.679350    0.942540
# k__Bacteria;p__Firmicutes;c__Erysipelotrichi;o_...  0.291728    0.055688
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...  0.000279    0.000204
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...  0.000000    0.000000
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...  0.001603    0.000000
#
# [9 rows x 298 columns]

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

sns.set(font="monospace")
sns.set_context("talk")

bt = load_table('stats/group-significance/no-diarrhea/taxa-summaries-5pct/otu_table.15000.no-diarrhea.5pct_L4.biom')

mf = load_mf('mapping-file-full.alpha.L6index.txt')
mf = mf.loc[bt.ids('sample')]

# dataframe from the group significance table
gsdf = pd.read_csv('stats/group-significance/no-diarrhea/kruskall-wallis-5pct-L4.tsv',
                   sep='\t')
gsdf = gsdf[gsdf['Bonferroni_P'] < 0.05]

current_palette = sns.color_palette()
cat_colors = dict(zip(mf.disease_stat.unique(),
                      current_palette[:3]))

# keep only the significant OTUs
bt.filter(gsdf.OTU.astype(str), axis='observation', inplace=True)
bt.norm()

df = exploding_panda(bt)

sample_order = mf[mf.disease_stat == 'healthy'].index.tolist() + mf[mf.disease_stat != 'healthy'].index.tolist()
df = df[sample_order]

colors = []
for sid in df.columns:
    colors.append(cat_colors[mf.loc[sid].disease_stat])

x = sns.clustermap(df, method="average",
                   row_cluster=True, col_cluster=False,
                   figsize=(20, 20), col_colors=colors,
                   cmap=plt.get_cmap("Oranges"))

handles = []
for key, value in cat_colors.iteritems():
    handles.append(mpatches.Patch(color=value, label=key))

plt.legend(handles=handles)
# x.savefig('clustermap-L6.pdf')
